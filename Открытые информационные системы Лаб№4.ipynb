# %%
import vk
import requests
"""
Функция для получения списка моих друзей

"""
def get_inf_friends(api, users_id):
    myDict = api.friends.get(user_id = users_id, fields = 'last_name')
    mylist = myDict.get('items')
    for i in range(194):
        getlist = dict(mylist[i])
        f_name = getlist.get('first_name')
        l_name = getlist.get('last_name')
        view = f_name + ' '+ l_name
        print(view)

session = vk.Session(access_token='d3b6f1b8b2d3a29c67ab5570a60805a48d334182c8a7dc291409cb6bc213e49201807c4bd1e26e7cdb3aa')
api = vk.API(session, v = '5.103')
get_inf_friends(api, '201574181')
profiles = api.users.get(user_id=1) #получение информации о пользователе с id = 1
print(profiles)
api.wall.post(owner_id='201574181', message="привет", v="5.92") #публикация поста на моей стене
# Out:
# Семён Уделов
# Ксения Елшина
# Вадим Гриних
# Дмитрий Чепак
# Алексей Лихов
# Владимир Красюк
# Александр Беляев
# Игорь Гулин
# Дмитрий Тиунов
# Алла Ахиярова
# Татьяна Ившина
# Ираида Гребнева
# Владимир Максимов
# DELETED
# Ольга Параничева
# Евгения Грибанова
# Наталья Черемных
# Дмитрий Лепешкин
# Radik Zaripov
# Аня Гущина
# Ольчик Меньшикова
# Alihan Dadashev
# Игорь Политов
# Александр Загидуллин
# Настя Каденова
# Никита Титов
# Александр Попов
# Александра Толстикова
# Иван Черемных
# Елизавета Орлецкая
# Сергей Неулыбин
# Максим Шардаков
# Анастасия Антипина
# Павел Макаров
# Руслан Раззаренов
# Тома Кобозева
# Владислав Рязанцев
# Гриша Романенко
# Михаил Кожемякин
# Николай Морозов
# Елена Корлякова-Васенина
# Павел Муратов
# Алина Подольская
# Екатерина Бояршинова
# Гертруда Андреищева
# Светлана Алтышева
# Станислав Лифанцев
# DELETED
# Антон Ивкин
# Иван Краснобаев
# Вероника Штейникова
# Юлия Тимиркина
# Дмитрий Минин
# Денис Казанцев
# Артём Наводничий
# ...
